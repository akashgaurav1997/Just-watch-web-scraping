# %% [markdown]
# <a href="https://colab.research.google.com/github/akashgaurav1997/Just-watch-web-scraping/blob/main/Copy_of_Numerical_Programming_in_Python_Web_Scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Web Scraping & Data Handling Challenge**

# %% [markdown]
# ### **Website:**
# JustWatch -  https://www.justwatch.com/in/movies?release_year_from=2000
#
#
# ### **Description:**
#
# JustWatch is a popular platform that allows users to search for movies and TV shows across multiple streaming services like Netflix, Amazon Prime, Hulu, etc. For this assignment, you will be required to scrape movie and TV show data from JustWatch using Selenium, Python, and BeautifulSoup. Extract data from HTML, not by directly calling their APIs. Then, perform data filtering and analysis using Pandas, and finally, save the results to a CSV file.
#
# ### **Tasks:**
#
# **1. Web Scraping:**
#
# Use BeautifulSoup to scrape the following data from JustWatch:
#
#    **a. Movie Information:**
#
#       - Movie title
#       - Release year
#       - Genre
#       - IMDb rating
#       - Streaming services available (Netflix, Amazon Prime, Hulu, etc.)
#       - URL to the movie page on JustWatch
#
#    **b. TV Show Information:**
#
#       - TV show title
#       - Release year
#       - Genre
#       - IMDb rating
#       - Streaming services available (Netflix, Amazon Prime, Hulu, etc.)
#       - URL to the TV show page on JustWatch
#
#   **c. Scope:**
#
# ```
#  ` - Scrape data for at least 50 movies and 50 TV shows.
#    - You can choose the entry point (e.g., starting with popular movies,
#      or a specific genre, etc.) to ensure a diverse dataset.`
#
# ```
#
#
# **2. Data Filtering & Analysis:**
#
#    After scraping the data, use Pandas to perform the following tasks:
#
#    **a. Filter movies and TV shows based on specific criteria:**
#
#    ```
#       - Only include movies and TV shows released in the last 2 years (from the current date).
#       - Only include movies and TV shows with an IMDb rating of 7 or higher.
# ```
#
#    **b. Data Analysis:**
#
#    ```
#       - Calculate the average IMDb rating for the scraped movies and TV shows.
#       - Identify the top 5 genres that have the highest number of available movies and TV shows.
#       - Determine the streaming service with the most significant number of offerings.
#
#    ```
#
# **3. Data Export:**
#
# ```
#    - Dump the filtered and analysed data into a CSV file for further processing and reporting.
#
#    - Keep the CSV file in your Drive Folder and Share the Drive link on the colab while keeping view access with anyone.
# ```
#
# **Submission:**
# ```
# - Submit a link to your Colab made for the assignment.
#
# - The Colab should contain your Python script (.py format only) with clear
#   comments explaining the scraping, filtering, and analysis process.
#
# - Your Code shouldn't have any errors and should be executable at a one go.
#
# - Before Conclusion, Keep your Dataset Drive Link in the Notebook.
# ```
#
#
#
# **Note:**
#
# 1. Properly handle errors and exceptions during web scraping to ensure a robust script.
#
# 2. Make sure your code is well-structured, easy to understand, and follows Python best practices.
#
# 3. The assignment will be evaluated based on the correctness of the scraped data, accuracy of data filtering and analysis, and the overall quality of the Python code.

# %% [markdown]
# # **Start The Project**

# %% [markdown]
# ## **Task 1:- Web Scrapping**

# %%
#Installing all necessary labraries
# !pip install bs4
# !pip install requests

# %%
#Import all necessary labraries:
import re   # (regular expression) for pattern matching and text manipulation:
import requests  # for making http request:
import numpy as np  # for numerical computing:
import pandas as pd  # for data manipulation and analysis:
from bs4 import BeautifulSoup  # for web scraping:
from wordcloud import WordCloud  # for creating word clouds from text data:
import matplotlib.pyplot as plt  # for creating visualizations:

# %% [markdown]
# ## **Scrapping Movies Data**

# %%
# Specifying the URL from which movies related data will be fetched
url='https://www.justwatch.com/in/movies?release_year_from=2000'

page = requests.get(url)

soup = BeautifulSoup(page.text, 'html.parser')
new_soup = soup.prettify()
print(new_soup)
# Out:
# <!DOCTYPE html>
# <html data-vue-meta="%7B%22dir%22:%7B%22ssr%22:%22ltr%22%7D,%22lang%22:%7B%22ssr%22:%22en%22%7D%7D" data-vue-meta-server-rendered="" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta charset="utf-8" data-vue-meta="ssr"/>
#   <meta content="IE=edge" data-vue-meta="ssr" httpequiv="X-UA-Compatible"/>
#   <meta content="viewport-fit=cover, width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no" data-vue-meta="ssr" name="viewport"/>
#   <meta content="JustWatch" data-vue-meta="ssr" property="og:site_name"/>
#   <meta content="794243977319785" data-vue-meta="ssr" property="fb:app_id"/>
#   <meta content="/appassets/img/JustWatch_logo_with_claim.png" data-vmid="og:image" data-vue-meta="ssr" property="og:image"/>
#   <meta content="606" data-vmid="og:image:width" data-vue-meta="ssr" property="og:image:width"/>
# ...

# %%
title = soup.find('title')
print(title)
# Out:
# <title>Watch movies online</title>

# %% [markdown]
# ## **Fetching Movie URL's**

# %%
# Extracting movies links:
l = soup.find_all('a')
for l2 in l:
  l3 = l2.get('href')
  if '2000' not in l3 and 'https' not in l3 and len(l3)>10:
    print(l3,len(l3))
# Out:
# /in/lists/public-lists 22
# /in/movie/dune-2021 19
# /in/movie/animal-2022 21
# /in/movie/salaar 16
# /in/movie/dunki 15
# /in/movie/12th-fail 19
# /in/movie/oppenheimer 21
# /in/movie/the-kerala-story 26
# /in/movie/anyone-but-you 24
# /in/movie/hanu-man 18
# /in/movie/sam-bahadur 21
# /in/movie/captain-miller 24
# /in/movie/ssmb-28 17
# /in/movie/ayalaan 17
# /in/movie/poor-things 21
# /in/movie/eagle-2024 20
# /in/movie/article-370 21
# /in/movie/untitled-shahid-kapoor-kriti-sanon-film 49
# /in/movie/aquaman-and-the-lost-kingdom 38
# /in/movie/fighter-2022 22
# /in/movie/bhakshak 18
# /in/movie/upgraded 18
# /in/movie/jawan 15
# /in/movie/neru 14
# /in/movie/the-marvels 21
# /in/movie/merry-christmas-2024 30
# /in/movie/anatomie-dune-chute 29
# /in/movie/code-8 16
# /in/movie/dune-part-two 23
# /in/movie/manjummel-boys 24
# /in/movie/365-days 18
# /in/movie/the-beekeeper-2024 28
# /in/movie/singapore-saloon 26
# /in/movie/migration 19
# /in/movie/untitled-cord-jefferson-film 38
# ...

# %%
# Creating movie urls and saving it in a list:
list_new_link = []

links = soup.find_all('a')

for link in links:
  link = link.get('href')
  if '2000' not in link and 'https' not in link and len(link)>10:
    new_link = 'https://www.justwatch.com'+link
    list_new_link.append(new_link)

# %%
index = 0
for i in list_new_link:
  print(index, i)
  index+=1
# Out:
# 0 https://www.justwatch.com/in/lists/public-lists
# 1 https://www.justwatch.com/in/movie/dune-2021
# 2 https://www.justwatch.com/in/movie/animal-2022
# 3 https://www.justwatch.com/in/movie/salaar
# 4 https://www.justwatch.com/in/movie/dunki
# 5 https://www.justwatch.com/in/movie/12th-fail
# 6 https://www.justwatch.com/in/movie/oppenheimer
# 7 https://www.justwatch.com/in/movie/the-kerala-story
# 8 https://www.justwatch.com/in/movie/anyone-but-you
# 9 https://www.justwatch.com/in/movie/hanu-man
# 10 https://www.justwatch.com/in/movie/sam-bahadur
# 11 https://www.justwatch.com/in/movie/captain-miller
# 12 https://www.justwatch.com/in/movie/ssmb-28
# 13 https://www.justwatch.com/in/movie/ayalaan
# 14 https://www.justwatch.com/in/movie/poor-things
# 15 https://www.justwatch.com/in/movie/eagle-2024
# 16 https://www.justwatch.com/in/movie/article-370
# 17 https://www.justwatch.com/in/movie/untitled-shahid-kapoor-kriti-sanon-film
# ...

# %%
#Creating dataframe extraction function:
def extract_data_frame(new_links, movie_or_show):
    extract_info = []

    for link in new_links:
        url2 = link
        page2 = requests.get(url2)
        soup2 = BeautifulSoup(page2.text, 'lxml')

        name = extract_name(soup2)
        year = extract_release_year(soup2)
        provider = extract_provider(soup2)
        genre = extract_genre_info(soup2)
        rating = extract_rating_info(soup2)
        runtime = extract_runtime_info(soup2)
        age_rating = extract_age_rating_info(soup2)
        country = extract_country_info(soup2)

        extract_info.append({movie_or_show: name, 'Year': year, 'Provider': provider, 'Genre':genre, 'Rating_Votes':rating, 'Runtime': runtime ,'Age_rating':age_rating,'Country':country})

    # Convert the list of dictionaries to a DataFrame
    df = pd.DataFrame(extract_info)
    return df

def extract_name(soup):
    names = soup.find_all('h1')
    for name in names:
        return name.text.strip()

def extract_release_year(soup):
    release_year = soup.find_all('span', class_='text-muted')
    for year in release_year:
        return year.text.strip()

def extract_provider(soup):
    pictures = soup.find_all('picture', class_='picture-wrapper')
    for picture in pictures:
        return picture.findChild('img').get('alt', 'No alt tag found')

def extract_genre_info(soup):
    genre_info = ""
    genre_infos = soup.find_all('div', class_='detail-infos')
    for genre in genre_infos:
        genre_subheading = genre.find('h3', class_='detail-infos__subheading')
        if genre_subheading and genre_subheading.text.strip() == 'Genres':
           genre_name = genre.find('div', class_='detail-infos__value').text.strip()
           genre_info = genre_name
    return genre_info


def extract_rating_info(soup):
    rating_info = ""
    rating_infos = soup.find_all('div', class_='detail-infos')
    for rating in rating_infos:
        rating_subheading = rating.find('h3', class_='detail-infos__subheading')
        if rating_subheading and rating_subheading.text.strip() == 'Rating':
           rating_name = rating.find('div', class_='detail-infos__value').text.strip()
           rating_info = rating_name
    return rating_info


def extract_runtime_info(soup):
    runtime_info = ""
    runtime_infos = soup.find_all('div', class_='detail-infos')
    for runtime in runtime_infos:
       runtime_subheading = runtime.find('h3', class_='detail-infos__subheading')
       if runtime_subheading and runtime_subheading.text.strip() == 'Runtime':
          runtime_name = runtime.find('div', class_='detail-infos__value').text.strip()
          runtime_info = runtime_name
    return runtime_info


def extract_age_rating_info(soup):
    age_rating_info = ""
    age_rating_infos = soup.find_all('div', class_='detail-infos')
    for rating in age_rating_infos:
       rating_subheading = rating.find('h3', class_='detail-infos__subheading')
       if rating_subheading and rating_subheading.text.strip() == 'Age rating':
          rating_name = rating.find('div', class_='detail-infos__value').text.strip()
          age_rating_info = rating_name
    return age_rating_info


def extract_country_info(soup):
    country_info = ""
    country_infos = soup.find_all('div', class_='detail-infos')
    for country in country_infos:
       country_subheading = country.find('h3', class_='detail-infos__subheading')
       if country_subheading and country_subheading.text.strip() == 'Production country':
          country_name = country.find('div', class_='detail-infos__value').text.strip()
          country_info = country_name
    return country_info

# %%
# Calling extract data frame function to extract movie data and convert it to a dataframe:
link = list_new_link
df_movies = extract_data_frame(link, 'Movie')

# %%
# Printing movie dataframe:
df_movies.head(5)
# Out:
#             Movie    Year  Provider  \
# 0            None    None      None
# 1    Dune  (2021)  (2021)  Apple TV
# 2  Animal  (2023)  (2023)   Netflix
# 3  Salaar  (2023)  (2023)   Netflix
# 4   Dunki  (2023)  (2023)   Netflix
#
#                                                Genre Rating_Votes   Runtime  \
# 0
# 1         Science-Fiction, Action & Adventure, Drama  8.0  (795k)  2h 35min
# 2  Action & Adventure, Crime, Drama, Mystery & Th...   6.3  (84k)  3h 21min
# 3  Mystery & Thriller, Action & Adventure, Crime,...   6.5  (61k)  2h 55min
# 4                                      Comedy, Drama   6.8  (69k)  2h 40min
#
#   Age_rating        Country
# 0
# 1         UA  United States
# 2          A          India
# 3          A          India
# 4                     India

# %% [markdown]
# ## **Scrapping Movie Title**

# %%
# Extracting movies name:
df_movies_name = df_movies['Movie']

# %%
# Printing movies name:
df_movies_name.head(5)
# Out:
# 0              None
# 1      Dune  (2021)
# 2    Animal  (2023)
# 3    Salaar  (2023)
# 4     Dunki  (2023)
# Name: Movie, dtype: object

# %%
df_movies_name.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 138 entries, 0 to 137
# Series name: Movie
# Non-Null Count  Dtype
# --------------  -----
# 137 non-null    object
# dtypes: object(1)
# memory usage: 1.2+ KB

# %% [markdown]
# ## **Scrapping release Year**

# %%
# Extracting release year:
df_movies_year = df_movies['Year']

# %%
# Printing movies year:
df_movies_year.head(5)
# Out:
# 0      None
# 1    (2021)
# 2    (2023)
# 3    (2023)
# 4    (2023)
# Name: Year, dtype: object

# %%
df_movies_year.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 138 entries, 0 to 137
# Series name: Year
# Non-Null Count  Dtype
# --------------  -----
# 120 non-null    object
# dtypes: object(1)
# memory usage: 1.2+ KB

# %% [markdown]
# ## **Scrapping Genres**

# %%
# Extracting movies genres:
df_movies_genre = df_movies['Genre']

# %%
# Printing movies genres:
df_movies_genre.head(5)
# Out:
# 0
# 1           Science-Fiction, Action & Adventure, Drama
# 2    Action & Adventure, Crime, Drama, Mystery & Th...
# 3    Mystery & Thriller, Action & Adventure, Crime,...
# 4                                        Comedy, Drama
# Name: Genre, dtype: object

# %%
df_movies_genre.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 138 entries, 0 to 137
# Series name: Genre
# Non-Null Count  Dtype
# --------------  -----
# 138 non-null    object
# dtypes: object(1)
# memory usage: 1.2+ KB

# %% [markdown]
# ## **Scrapping IMBD Rating**

# %%
# Extracting movies rating:
df_movies_rating = df_movies['Rating_Votes']

# %%
# Printing movies rating:
df_movies_rating.head(5)
# Out:
# 0
# 1    8.0  (795k)
# 2     6.3  (84k)
# 3     6.5  (61k)
# 4     6.8  (69k)
# Name: Rating_Votes, dtype: object

# %%
df_movies_rating.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 138 entries, 0 to 137
# Series name: Rating_Votes
# Non-Null Count  Dtype
# --------------  -----
# 138 non-null    object
# dtypes: object(1)
# memory usage: 1.2+ KB

# %% [markdown]
# ## **Scrapping Runtime/Duration**

# %%
# Extracting movies runtime:
df_movies_runtime = df_movies['Runtime']

# %%
# Printing movies runtime:
df_movies_runtime.head(5)
# Out:
# 0
# 1    2h 35min
# 2    3h 21min
# 3    2h 55min
# 4    2h 40min
# Name: Runtime, dtype: object

# %%
df_movies_runtime.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 138 entries, 0 to 137
# Series name: Runtime
# Non-Null Count  Dtype
# --------------  -----
# 138 non-null    object
# dtypes: object(1)
# memory usage: 1.2+ KB

# %% [markdown]
# ## **Scrapping Age Rating**

# %%
# Extracting movies age rating:
df_movies_age_rating = df_movies['Age_rating']

# %%
# Printing movies age rating:
df_movies_age_rating.head(5)
# Out:
# 0
# 1    UA
# 2     A
# 3     A
# 4
# Name: Age_rating, dtype: object

# %%
df_movies_age_rating.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 138 entries, 0 to 137
# Series name: Age_rating
# Non-Null Count  Dtype
# --------------  -----
# 138 non-null    object
# dtypes: object(1)
# memory usage: 1.2+ KB

# %% [markdown]
# ## **Fetching Production Countries Details**

# %%
# Extracting movies production country:
df_movies_country = df_movies['Country']

# %%
# Printing movies production country:
df_movies_country.head(5)
# Out:
# 0
# 1    United States
# 2            India
# 3            India
# 4            India
# Name: Country, dtype: object

# %%
df_movies_country.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 138 entries, 0 to 137
# Series name: Country
# Non-Null Count  Dtype
# --------------  -----
# 138 non-null    object
# dtypes: object(1)
# memory usage: 1.2+ KB

# %% [markdown]
# ## **Fetching Streaming Service Details**

# %%
# Extracting movies streaming provider:
df_movies_provider = df_movies['Provider']

# %%
# Printing movies streaming provider:
df_movies_provider.head(10)
# Out:
# 0        None
# 1    Apple TV
# 2     Netflix
# 3     Netflix
# 4     Netflix
# 5     Hotstar
# 6    Apple TV
# 7        Zee5
# 8    Apple TV
# 9        None
# Name: Provider, dtype: object

# %%
df_movies_provider.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 138 entries, 0 to 137
# Series name: Provider
# Non-Null Count  Dtype
# --------------  -----
# 103 non-null    object
# dtypes: object(1)
# memory usage: 1.2+ KB

# %% [markdown]
# ## **Now Creating Movies DataFrame**

# %%
#Printing movie dataframe:
df_movies.head(5)
# Out:
#             Movie    Year  Provider  \
# 0            None    None      None
# 1    Dune  (2021)  (2021)  Apple TV
# 2  Animal  (2023)  (2023)   Netflix
# 3  Salaar  (2023)  (2023)   Netflix
# 4   Dunki  (2023)  (2023)   Netflix
#
#                                                Genre Rating_Votes   Runtime  \
# 0
# 1         Science-Fiction, Action & Adventure, Drama  8.0  (795k)  2h 35min
# 2  Action & Adventure, Crime, Drama, Mystery & Th...   6.3  (84k)  3h 21min
# 3  Mystery & Thriller, Action & Adventure, Crime,...   6.5  (61k)  2h 55min
# 4                                      Comedy, Drama   6.8  (69k)  2h 40min
#
#   Age_rating        Country
# 0
# 1         UA  United States
# 2          A          India
# 3          A          India
# 4                     India

# %% [markdown]
# ## **Scraping TV  Show Data**

# %%
# Specifying the URL from which tv show related data will be fetched:
tv_url = 'https://www.justwatch.com/in/tv-shows?release_year_from=2000'
# Sending an HTTP GET request to the URL:
tv_page = requests.get(tv_url)
# Parsing the HTML content using BeautifulSoup with the 'html.parser':
tv_soup = BeautifulSoup(tv_page.text,'html.parser')
# Printing the prettified HTML content:
print(tv_soup.prettify())
# Out:
# <!DOCTYPE html>
# <html data-vue-meta="%7B%22dir%22:%7B%22ssr%22:%22ltr%22%7D,%22lang%22:%7B%22ssr%22:%22en%22%7D%7D" data-vue-meta-server-rendered="" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta charset="utf-8" data-vue-meta="ssr"/>
#   <meta content="IE=edge" data-vue-meta="ssr" httpequiv="X-UA-Compatible"/>
#   <meta content="viewport-fit=cover, width=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no" data-vue-meta="ssr" name="viewport"/>
#   <meta content="JustWatch" data-vue-meta="ssr" property="og:site_name"/>
#   <meta content="794243977319785" data-vue-meta="ssr" property="fb:app_id"/>
#   <meta content="/appassets/img/JustWatch_logo_with_claim.png" data-vmid="og:image" data-vue-meta="ssr" property="og:image"/>
#   <meta content="606" data-vmid="og:image:width" data-vue-meta="ssr" property="og:image:width"/>
# ...

# %% [markdown]
# ## **Fetching Tv shows Url details**

# %%
# Extracting tv-shows links:
tv_link = tv_soup.find_all('a')
for l2 in tv_link:
  l3 = l2.get('href')
  if '2000' not in l3 and 'https' not in l3 and len(l3)>10:
    print(l3,len(l3))
# Out:
# /in/lists/public-lists 22
# /in/tv-show/panchayat 21
# /in/tv-show/game-of-thrones 27
# /in/tv-show/mirzapur 20
# /in/tv-show/shogun-2024 23
# /in/tv-show/true-detective 26
# /in/tv-show/avatar-the-last-airbender 37
# /in/tv-show/one-day 19
# /in/tv-show/aarya 17
# /in/tv-show/solo-leveling-2024 30
# /in/tv-show/sunflower-2021 26
# /in/tv-show/halo 16
# /in/tv-show/indian-police-force 31
# /in/tv-show/death-and-other-details 35
# /in/tv-show/young-sheldon 25
# /in/tv-show/poacher 19
# /in/tv-show/mastram 19
# /in/tv-show/farzi 17
# /in/tv-show/the-twelve 22
# /in/tv-show/jujutsu-kaisen 26
# /in/tv-show/yellowstone 23
# /in/tv-show/maharani-2021 25
# /in/tv-show/avatar-the-last-airbender-2005 42
# /in/tv-show/jack-reacher 24
# /in/tv-show/maamla-legal-hai 28
# /in/tv-show/criminal-justice-2019 33
# /in/tv-show/bigg-boss 21
# /in/tv-show/loki 16
# /in/tv-show/paperhouse 22
# /in/tv-show/scam-1992 21
# /in/tv-show/aashram 19
# /in/tv-show/the-rookie 22
# /in/tv-show/lucifer 19
# ...

# %%
# Creating tv-shows urls and saving in a list:
tv_list_links = []

tv_links = tv_soup.find_all('a')

for link in tv_links:
  link = link.get('href')
  if '2000' not in link and 'https' not in link and len(link)>10:
    new_link = 'https://www.justwatch.com'+link
    tv_list_links.append(new_link)

# %%
# Printing the tv-shows urls:
index = 0
for i in tv_list_links:
  print(index, i)
  index+=1
# Out:
# 0 https://www.justwatch.com/in/lists/public-lists
# 1 https://www.justwatch.com/in/tv-show/panchayat
# 2 https://www.justwatch.com/in/tv-show/game-of-thrones
# 3 https://www.justwatch.com/in/tv-show/mirzapur
# 4 https://www.justwatch.com/in/tv-show/shogun-2024
# 5 https://www.justwatch.com/in/tv-show/true-detective
# 6 https://www.justwatch.com/in/tv-show/avatar-the-last-airbender
# 7 https://www.justwatch.com/in/tv-show/one-day
# 8 https://www.justwatch.com/in/tv-show/aarya
# 9 https://www.justwatch.com/in/tv-show/solo-leveling-2024
# 10 https://www.justwatch.com/in/tv-show/sunflower-2021
# 11 https://www.justwatch.com/in/tv-show/halo
# 12 https://www.justwatch.com/in/tv-show/indian-police-force
# 13 https://www.justwatch.com/in/tv-show/death-and-other-details
# 14 https://www.justwatch.com/in/tv-show/young-sheldon
# 15 https://www.justwatch.com/in/tv-show/poacher
# 16 https://www.justwatch.com/in/tv-show/mastram
# 17 https://www.justwatch.com/in/tv-show/farzi
# ...

# %% [markdown]
# ##Creating tv_show dataframe using extract dataframe function:

# %%
# Calling extract dataframe function to extract tv-show data and convert it to a dataframe:
tv_link = tv_list_links
df_shows = extract_data_frame(tv_link, 'TV-show')

# %%
# Printing tv-show dataframe:
df_shows.head(5)
# Out:
#                    TV-show    Year            Provider  \
# 0                     None    None                None
# 1        Panchayat  (2020)  (2020)  Amazon Prime Video
# 2  Game of Thrones  (2011)  (2011)          Jio Cinema
# 3         Mirzapur  (2018)  (2018)  Amazon Prime Video
# 4           Shōgun  (2024)  (2024)             Hotstar
#
#                                                Genre Rating_Votes Runtime  \
# 0
# 1                                      Comedy, Drama   8.9  (83k)   33min
# 2  Drama, Action & Adventure, Science-Fiction, Fa...    9.2  (2m)   58min
# 3  Crime, Action & Adventure, Drama, Mystery & Th...   8.5  (81k)   50min
# 4                     Drama, History, War & Military   9.2  (21k)   57min
#
#   Age_rating        Country
# 0
# 1                     India
# 2          U  United States
# 3                     India
# 4             United States

# %%
df_shows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138 entries, 0 to 137
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   TV-show       137 non-null    object
#  1   Year          120 non-null    object
#  2   Provider      108 non-null    object
#  3   Genre         138 non-null    object
#  4   Rating_Votes  138 non-null    object
#  5   Runtime       138 non-null    object
#  6   Age_rating    138 non-null    object
#  7   Country       138 non-null    object
# dtypes: object(8)
# memory usage: 8.8+ KB

# %% [markdown]
# ## **Fetching Tv Show Title details**

# %%
# Extracting tv-shows name:
df_shows_name = df_shows['TV-show']

# %%
# Printing tv-shows name:
df_shows_name.head(5)
# Out:
# 0                       None
# 1          Panchayat  (2020)
# 2    Game of Thrones  (2011)
# 3           Mirzapur  (2018)
# 4             Shōgun  (2024)
# Name: TV-show, dtype: object

# %%
df_shows_name.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 138 entries, 0 to 137
# Series name: TV-show
# Non-Null Count  Dtype
# --------------  -----
# 137 non-null    object
# dtypes: object(1)
# memory usage: 1.2+ KB

# %% [markdown]
# ## **Fetching Release Year**

# %%
# Extracting tv-shows release year:
df_shows_year = df_shows['Year']

# %%
# Printing tv-shows release year:
df_shows_year.head(5)
# Out:
# 0      None
# 1    (2020)
# 2    (2011)
# 3    (2018)
# 4    (2024)
# Name: Year, dtype: object

# %%
df_shows_year.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 138 entries, 0 to 137
# Series name: Year
# Non-Null Count  Dtype
# --------------  -----
# 120 non-null    object
# dtypes: object(1)
# memory usage: 1.2+ KB

# %% [markdown]
# ## **Fetching TV Show Genre Details**

# %%
# Extracting tv-shows genre:
df_shows_genre = df_shows['Genre']

# %%
#Printing tv-shows genre:
df_shows_genre.head(5)
# Out:
# 0
# 1                                        Comedy, Drama
# 2    Drama, Action & Adventure, Science-Fiction, Fa...
# 3    Crime, Action & Adventure, Drama, Mystery & Th...
# 4                       Drama, History, War & Military
# Name: Genre, dtype: object

# %% [markdown]
# ## **Fetching IMDB Rating Details**

# %%
# Extracting tv-show rating:
df_shows_rating = df_shows['Rating_Votes']

# %%
#Printing tv-shows rating:
df_shows_rating.head(5)
# Out:
# 0
# 1    8.9  (83k)
# 2     9.2  (2m)
# 3    8.5  (81k)
# 4    9.2  (21k)
# Name: Rating_Votes, dtype: object

# %% [markdown]
# ## **Fetching Age Rating Details**

# %%
# Extracting tv-shows age rating:
df_shows_age_rating = df_shows['Age_rating']

# %%
#Printing tv-shows age rating:
df_shows_age_rating.head(5)
# Out:
# 0
# 1
# 2    U
# 3
# 4
# Name: Age_rating, dtype: object

# %% [markdown]
# ## **Fetching Production Country details**

# %%
# Extracting tv-shows production country:
df_shows_country = df_shows['Country']

# %%
#Printing tv-shows production country:
df_shows_country.head(5)
# Out:
# 0
# 1            India
# 2    United States
# 3            India
# 4    United States
# Name: Country, dtype: object

# %% [markdown]
# ## **Fetching Streaming Service details**

# %%
# Extracting tv-shows streaming service provider:
df_shows_provider = df_shows['Provider']

# %%
#Printing tv-shows streaming service provider:
df_shows_provider.head(5)
# Out:
# 0                  None
# 1    Amazon Prime Video
# 2            Jio Cinema
# 3    Amazon Prime Video
# 4               Hotstar
# Name: Provider, dtype: object

# %% [markdown]
# ## **Fetching Duration Details**

# %%
# Extracting tv-shows runtime:
df_shows_runtime = df_shows['Runtime']

# %%
#Printing tv-shows runtime:
df_shows_runtime.head(5)
# Out:
# 0
# 1    33min
# 2    58min
# 3    50min
# 4    57min
# Name: Runtime, dtype: object

# %% [markdown]
# ## **Creating TV Show DataFrame**

# %%
# Printing tv-shows dataframe:
df_shows.head(10)
# Out:
#                               TV-show    Year            Provider  \
# 0                                None    None                None
# 1                   Panchayat  (2020)  (2020)  Amazon Prime Video
# 2             Game of Thrones  (2011)  (2011)          Jio Cinema
# 3                    Mirzapur  (2018)  (2018)  Amazon Prime Video
# 4                      Shōgun  (2024)  (2024)             Hotstar
# 5              True Detective  (2014)  (2014)          Jio Cinema
# 6  Avatar: The Last Airbender  (2024)  (2024)             Netflix
# 7                     One Day  (2024)  (2024)             Netflix
# 8                       Aarya  (2020)  (2020)             Hotstar
# 9               Solo Leveling  (2024)  (2024)         Crunchyroll
#
#                                                Genre Rating_Votes  Runtime  \
# 0
# 1                                      Comedy, Drama   8.9  (83k)    33min
# 2  Drama, Action & Adventure, Science-Fiction, Fa...    9.2  (2m)    58min
# ...

# %% [markdown]
# ## **Task 2 :- Data Filtering & Analysis**

# %% [markdown]
# ####Data Cleaning Of Movies Dataframe:

# %%
# Non-value count and datatypes:
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138 entries, 0 to 137
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Movie         137 non-null    object
#  1   Year          120 non-null    object
#  2   Provider      103 non-null    object
#  3   Genre         138 non-null    object
#  4   Rating_Votes  138 non-null    object
#  5   Runtime       138 non-null    object
#  6   Age_rating    138 non-null    object
#  7   Country       138 non-null    object
# dtypes: object(8)
# memory usage: 8.8+ KB

# %%
# Removing non-numeric characters from 'Year' column:
df_movies['Year'] = df_movies['Year'].str.extract(r'(\d+)')

# Converting the 'Year' column to integer data type:
df_movies['Year'] = df_movies['Year'].fillna(0).astype(int)

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138 entries, 0 to 137
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Movie         137 non-null    object
#  1   Year          138 non-null    int64
#  2   Provider      103 non-null    object
#  3   Genre         138 non-null    object
#  4   Rating_Votes  138 non-null    object
#  5   Runtime       138 non-null    object
#  6   Age_rating    138 non-null    object
#  7   Country       138 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 8.8+ KB

# %%
# Extracting name of movies from movie column:
df_movies['Movie'] = df_movies['Movie'].str.extract(r'^(.*?)\s*\(\d+\)$')

# %%
df_movies.head(5)
# Out:
#     Movie  Year  Provider                                              Genre  \
# 0     NaN     0      None
# 1    Dune  2021  Apple TV         Science-Fiction, Action & Adventure, Drama
# 2  Animal  2023   Netflix  Action & Adventure, Crime, Drama, Mystery & Th...
# 3  Salaar  2023   Netflix  Mystery & Thriller, Action & Adventure, Crime,...
# 4   Dunki  2023   Netflix                                      Comedy, Drama
#
#   Rating_Votes   Runtime Age_rating        Country
# 0
# 1  8.0  (795k)  2h 35min         UA  United States
# 2   6.3  (84k)  3h 21min          A          India
# 3   6.5  (61k)  2h 55min          A          India
# 4   6.8  (69k)  2h 40min                     India

# %% [markdown]
# ####Data Cleaning Of TV-Shows Dataframe:

# %%
# Non-null counts and datatype:
df_shows.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138 entries, 0 to 137
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   TV-show       137 non-null    object
#  1   Year          120 non-null    object
#  2   Provider      108 non-null    object
#  3   Genre         138 non-null    object
#  4   Rating_Votes  138 non-null    object
#  5   Runtime       138 non-null    object
#  6   Age_rating    138 non-null    object
#  7   Country       138 non-null    object
# dtypes: object(8)
# memory usage: 8.8+ KB

# %%
# Removing non-numeric characters from 'Year' column:
df_shows['Year'] = df_shows['Year'].str.extract(r'(\d+)')

# Converting the 'Year' column to integer data type:
df_shows['Year'] = df_shows['Year'].fillna(0).astype(int)

# %%
# Extracting name of tv-shows from tv-show column:
df_shows['TV-show'] = df_shows['TV-show'].str.extract(r'^(.*?)\s*\(\d+\)$')

# %%
df_shows.head(5)
# Out:
#            TV-show  Year            Provider  \
# 0              NaN     0                None
# 1        Panchayat  2020  Amazon Prime Video
# 2  Game of Thrones  2011          Jio Cinema
# 3         Mirzapur  2018  Amazon Prime Video
# 4           Shōgun  2024             Hotstar
#
#                                                Genre Rating_Votes Runtime  \
# 0
# 1                                      Comedy, Drama   8.9  (83k)   33min
# 2  Drama, Action & Adventure, Science-Fiction, Fa...    9.2  (2m)   58min
# 3  Crime, Action & Adventure, Drama, Mystery & Th...   8.5  (81k)   50min
# 4                     Drama, History, War & Military   9.2  (21k)   57min
#
#   Age_rating        Country
# 0
# 1                     India
# 2          U  United States
# 3                     India
# 4             United States

# %% [markdown]
# ####Extracting Rating From Rating_Votes Column And Creating A New Rating Column:

# %%
# Extracting rating for movies:
# Converting to a string:
rating_string = df_movies['Rating_Votes'].str

# Extracting rating:
df_movies['Rating'] = rating_string.extract(r'^(\d+\.\d+)').astype(float)

# %%
df_movies.head(5)
# Out:
#     Movie  Year  Provider                                              Genre  \
# 0     NaN     0      None
# 1    Dune  2021  Apple TV         Science-Fiction, Action & Adventure, Drama
# 2  Animal  2023   Netflix  Action & Adventure, Crime, Drama, Mystery & Th...
# 3  Salaar  2023   Netflix  Mystery & Thriller, Action & Adventure, Crime,...
# 4   Dunki  2023   Netflix                                      Comedy, Drama
#
#   Rating_Votes   Runtime Age_rating        Country  Rating
# 0                                                      NaN
# 1  8.0  (795k)  2h 35min         UA  United States     8.0
# 2   6.3  (84k)  3h 21min          A          India     6.3
# 3   6.5  (61k)  2h 55min          A          India     6.5
# 4   6.8  (69k)  2h 40min                     India     6.8

# %%
# Extracting rating for tv-shows:
# Converting to a string:
rating_string2 = df_shows['Rating_Votes'].str

# Extracting rating:
df_shows['Rating'] = rating_string2.extract(r'^(\d+\.\d+)').astype(float)

# %%
df_shows.head(5)
# Out:
#            TV-show  Year            Provider  \
# 0              NaN     0                None
# 1        Panchayat  2020  Amazon Prime Video
# 2  Game of Thrones  2011          Jio Cinema
# 3         Mirzapur  2018  Amazon Prime Video
# 4           Shōgun  2024             Hotstar
#
#                                                Genre Rating_Votes Runtime  \
# 0
# 1                                      Comedy, Drama   8.9  (83k)   33min
# 2  Drama, Action & Adventure, Science-Fiction, Fa...    9.2  (2m)   58min
# 3  Crime, Action & Adventure, Drama, Mystery & Th...   8.5  (81k)   50min
# 4                     Drama, History, War & Military   9.2  (21k)   57min
#
#   Age_rating        Country  Rating
# 0                               NaN
# 1                     India     8.9
# 2          U  United States     9.2
# 3                     India     8.5
# 4             United States     9.2

# %% [markdown]
# ####Handling NaN  Rows In Rating Column:

# %%
# Handling NaN rows in rating column in movies  and shows dataset:
df_movies['Rating'].fillna(0, inplace = True)
df_shows['Rating'].fillna(0, inplace = True)

# %%
df_movies['Rating'].isna().sum()
# Out:
# 0

# %%
df_shows['Rating'].isna().sum()
# Out:
# 0

# %% [markdown]
# ## **Calculating Mean IMDB Ratings for both Movies and Tv Shows**

# %%
# Caluculating mean rating of movies:
movies_avg = df_movies['Rating'].mean()

# %%
# Printing movies mean rating:
movies_avg
# Out:
# 5.760869565217392

# %%
# Caluculating mean rating of tv-shows:
shows_avg = df_shows['Rating'].mean()

# %%
# Printing shows mean rating:
shows_avg
# Out:
# 6.171014492753622

# %% [markdown]
# ## **Analyzing Top Genres**

# %% [markdown]
# ####Movies Genre Counts And Visualization:

# %%
# Extracting each movie genre from each row of the column:
movies_genre = df_movies['Genre'].str.split(', ', expand=True).stack()

# %%
# Extracting and printing movies genre counts:
movies_genre_counts = movies_genre.value_counts()
movies_genre_counts
# Out:
# Drama                 87
# Action & Adventure    54
# Mystery & Thriller    45
# Comedy                34
# Crime                 25
# Science-Fiction       22
#                       18
# Romance               18
# Fantasy               18
# History               17
# Kids & Family         11
# War & Military         9
# Animation              5
# Horror                 4
# Made in Europe         2
# Sport                  2
# Western                2
# Documentary            1
# Music & Musical        1
# dtype: int64

# %%
# visualizing movies genre counts using wordcloud:

# Generating word cloud:
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(movies_genre_counts)

# Ploting word cloud:
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ####TV-Shows Genre Counts And Visualization:

# %%
# Extracting each show genre in each row of the column:
shows_genre = df_shows['Genre'].str.split(', ', expand=True).stack()

# %%
# Printing shows genre counts:
shows_genre_counts = shows_genre.value_counts()
shows_genre_counts
# Out:
# Drama                 95
# Action & Adventure    46
# Mystery & Thriller    43
# Crime                 38
# Science-Fiction       36
# Comedy                33
# Fantasy               32
#                       18
# Romance               14
# Animation             13
# History                9
# Kids & Family          8
# War & Military         6
# Horror                 4
# Reality TV             2
# Made in Europe         2
# Documentary            2
# Western                1
# Music & Musical        1
# dtype: int64

# %%
# visualizing movies genre counts using wordcloud:

# Generating word cloud:
wordcloud2 = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(shows_genre_counts)

# Ploting word cloud:
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud2, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ## **Finding Predominant Streaming Service**

# %% [markdown]
# ####Movies Streaming Service Provider Counts And Visualization:

# %%
# Counting each movies provider:
movies_provider = df_movies['Provider']
movies_provider_counts = movies_provider.value_counts()

# %%
# Printing movies provider counts:
movies_provider_counts
# Out:
# Amazon Prime Video    27
# Apple TV              26
# Netflix               18
# Hotstar                9
# Bookmyshow             9
# Zee5                   4
# Jio Cinema             4
# Lionsgate Play         2
# Apple TV Plus          2
# Sun Nxt                1
# Sony Liv               1
# Name: Provider, dtype: int64

# %%
# visualizing movies genre counts using wordcloud:

# Generating word cloud:
wordcloud3 = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(movies_provider_counts)

# Ploting word cloud:
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud3, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ####Tv-Shows Streaming Service Provider And Visualization:

# %%
# Counting each tv-show provider:
shows_provider = df_shows['Provider']
shows_provider_counts = shows_provider.value_counts()

# %%
# Printing tv-shows provider counts:
shows_provider_counts
# Out:
# Netflix               35
# Amazon Prime Video    22
# Jio Cinema            15
# Hotstar               14
# Sony Liv               7
# Crunchyroll            6
# Apple TV Plus          3
# Lionsgate Play         2
# VI movies and tv       1
# MX Player              1
# Alt Balaji             1
# Apple TV               1
# Name: Provider, dtype: int64

# %%
# visualizing tv-shows provider counts using wordcloud:

# Generating word cloud:
wordcloud4 = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(shows_provider_counts)

# Ploting word cloud:
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud4, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ## **Task 3 :- Data Export**

# %%
# Mounting drive:
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# saving final dataframe of movies as Final Data in csv format:
df_movies.to_csv('/content/drive/MyDrive/df_movies.csv', index=False)

# %%
# saving final dataframe of tv-shows as Final Data in csv format:
df_shows.to_csv('/content/drive/MyDrive/df_shows.csv', index=False)

# %% [markdown]
# # **Dataset Drive Link (View Access with Anyone) -**
# * Movie Dataset :- https://drive.google.com/file/d/14BK6e2d49iuAL6oag67XKPytZ0avEuWE/view?usp=sharing
#
# * TV-Show Dataset :- https://drive.google.com/file/d/1--oyGvqo0Zq_oJiMICgP8grMAnykkDjE/view?usp=sharing

# %% [markdown]
# # ***Congratulations!!! You have completed your Assignment.***
